# %% [markdown]
# <a href="https://colab.research.google.com/github/joehawkens/MachineLearning/blob/main/MODULE_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MODULE 4
# ## Target: Predict the number of bicycle rentals for a given day. - Casual + Registered
# - Data Dictionary: https://byui-cse.github.io/cse450-course/module-04/bikes-dictionary.txt
# - Data: https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bikes.csv

# %%
import pandas as pd
rental_data = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bikes.csv')
rental_data.describe()
# Out:
#              season            hr       holiday    workingday    weathersit  \
# count  16637.000000  16637.000000  16637.000000  16637.000000  16637.000000
# mean       2.482058     11.547875      0.028671      0.684378      1.415580
# std        1.085930      6.914199      0.166885      0.464777      0.637298
# min        1.000000      0.000000      0.000000      0.000000      1.000000
# 25%        2.000000      6.000000      0.000000      0.000000      1.000000
# 50%        2.000000     12.000000      0.000000      1.000000      1.000000
# 75%        3.000000     18.000000      0.000000      1.000000      2.000000
# max        4.000000     23.000000      1.000000      1.000000      4.000000
#
#                 hum     windspeed        temp_c  feels_like_c        casual  \
# count  16637.000000  16637.000000  16637.000000  16637.000000  16637.000000
# mean       0.624756     12.750436     15.723008     15.852141     36.471239
# ...

# %%
# - holiday : weather day is holiday or not
# - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# Learning rate: 1 x 10 -5
